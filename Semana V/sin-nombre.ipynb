# %% [markdown]
# ### Para rutas en Windows

# %%
print("\n")

# %%
print('Estas son comillas simples: \'\'')
# Out:
# Estas son comillas simples: ''

# %%
print("Estas son comillas dobles: \"\"")
# Out:
# Estas son comillas dobles: ""

# %%
"C:\\Users\\me\\Documentos\\patitoafeo.txt"
# Out:
# 'C:\\Users\\me\\Documentos\\patitofeo.txt'

# %%
r"C:\Users\me\Documentos\patitoafeo.txt"
# Out:
# 'C:\\Users\\me\\Documentos\\patitoafeo.txt'

# %% [markdown]
# ----

# %% [markdown]
# # I/O

# %%
# Si la ruta no existe, devuelve FileNotFoundError 
# open("/Users/miguelcamargorojas/Documents/UP/POO-Gpo2-2026/Semana V/patitofeo.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 open("/Users/miguelcamargorojas/Documents/UP/POO-Gpo2-2026/Semana V/patitofeo.txt")
#
# File ~/Library/Python/3.14/lib/python/site-packages/IPython/core/interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/miguelcamargorojas/Documents/UP/POO-Gpo2-2026/Semana V/patitofeo.txt'

# %%
# En modo w, si no existe el archivo lo crea, si existe, lo sobreescribe
open("/Users/miguelcamargorojas/Documents/UP/POO-Gpo2-2026/Semana V/test.txt", 'w')
# Out:
# <_io.TextIOWrapper name='/Users/miguelcamargorojas/Documents/UP/POO-Gpo2-2026/Semana V/test.txt' mode='w' encoding='UTF-8'>

# %% [markdown]
# ### Método 1

# %%
# En modo w, si no existe el archivo lo crea, si existe, lo sobreescribe
manejador = open("/Users/miguelcamargorojas/Documents/UP/POO-Gpo2-2026/Semana V/test.txt", 'w')
## 1000 líneas
# Tengo que cerrar manualmente
# manejador.close()

# %%
type(manejador)
# Out:
# _io.TextIOWrapper

# %%
dir(manejador)
# Out:
# ['_CHUNK_SIZE',
#  '__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_checkClosed',
#  '_checkReadable',
#  '_checkSeekable',
#  '_checkWritable',
#  '_finalizing',
#  'buffer',
#  'close',
#  'closed',
#  'detach',
#  'encoding',
#  'errors',
#  'fileno',
#  'flush',
#  'isatty',
#  'line_buffering',
#  'mode',
#  'name',
#  'newlines',
#  'read',
#  'readable',
#  'readline',
#  'readlines',
#  'reconfigure',
#  'seek',
#  'seekable',
#  'tell',
#  'truncate',
#  'writable',
#  'write',
#  'write_through',
#  'writelines']

# %%
# En modo w, si no existe el archivo lo crea, si existe, lo sobreescribe
manejador = open("/Users/miguelcamargorojas/Documents/UP/POO-Gpo2-2026/Semana V/test.txt", 'w')
## 1000 líneas
manejador.write("Hola mundo (persistente)")
# Tengo que cerrar manualmente
manejador.close()

# %%
# En modo w, si no existe el archivo lo crea, si existe, lo sobreescribe
manejador = open("/Users/miguelcamargorojas/Documents/UP/POO-Gpo2-2026/Semana V/test.txt", 'w')
## 1000 líneas
manejador.write("Saludos alumnos de la UP")
# Tengo que cerrar manualmente
manejador.close()

# %% [markdown]
# ## Método 2

# %%
with open("/Users/miguelcamargorojas/Documents/UP/POO-Gpo2-2026/Semana V/test.txt", 'r') as m:
    print(m.read()) # Nos evitamos el close()
# Out:
# Saludos alumnos de la UP

# %%
with open("/Users/miguelcamargorojas/Documents/UP/POO-Gpo2-2026/Semana V/test.txt", 'a') as m:
    m.write("\nPython es lo máximo") # Nos evitamos el close()

# %%
texto = """Hola mundo.
Saludos alumnos de POO.
No vayan a reprobar, por favor.
Participen más en clase, gracias.
=)"""
with open("/Users/miguelcamargorojas/Documents/UP/POO-Gpo2-2026/Semana V/test.txt", 'w') as m:
    m.write(texto) # Nos evitamos el close()

# %%
list_texto = ["Hola mundo.\n",
"Saludos alumnos de POO.\n",
"No vayan a reprobar, por favor.\n",
"Participen más en clase, gracias.\n",
"=)"]
with open("/Users/miguelcamargorojas/Documents/UP/POO-Gpo2-2026/Semana V/test.txt", 'w') as m:
    m.writelines(list_texto) # Nos evitamos el close()

# %%
# # Open espera abrir un archivo no una ruta (carpeta)
# with open("/Users/miguelcamargorojas/Documents/UP/POO-Gpo2-2026/Semana V", 'w') as m:
#     # m.writelines(list_texto) # Nos evitamos el close()
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Open espera abrir un archivo no una ruta (carpeta)
# ----> 2 with open("/Users/miguelcamargorojas/Documents/UP/POO-Gpo2-2026/Semana V", 'w') as m:
#       3     m.writelines(list_texto) # Nos evitamos el close()
#
# File ~/Library/Python/3.14/lib/python/site-packages/IPython/core/interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# IsADirectoryError: [Errno 21] Is a directory: '/Users/miguelcamargorojas/Documents/UP/POO-Gpo2-2026/Semana V'

# %% [markdown]
# ---
# # Tiempo

# %%
import time

# %%
time.time()
# Out:
# 1771429077.5336199

# %%
t_inicial = time.time()
list_texto = ["Hola mundo.\n",
"Saludos alumnos de POO.\n",
"No vayan a reprobar, por favor.\n",
"Participen más en clase, gracias.\n",
"=)"]
with open("/Users/miguelcamargorojas/Documents/UP/POO-Gpo2-2026/Semana V/test.txt", 'w') as m:
    m.writelines(list_texto) # Nos evitamos el close()

t_final = time.time()

print(f'Tiempo transcurrido: {t_final - t_inicial}')
# Out:
# Tiempo transcurrido: 0.0016100406646728516
