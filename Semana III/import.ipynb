# %% [markdown]
# Nota: En Python no se llaman librerías, se llaman módulos

# %%
import math

# %%
math.sin(0)
# Out:
# 0.0

# %%
math.cos(1)
# Out:
# 0.5403023058681398

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
math.pi
# Out:
# 3.141592653589793
