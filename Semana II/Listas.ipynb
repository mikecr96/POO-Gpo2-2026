# %%
len("Hola mundo")
# Out:
# 10

# %% [markdown]
# # Listas en Python

# %%
lista = [1, 2, 3, 4, 3.14, True, (1, 2, 3), "Hola"]

# %%
len(lista)
# Out:
# 8

# %%
lista[0]
# Out:
# 1

# %%
lista[5]
# Out:
# True

# %%
lista[-1]
# Out:
# 'Hola'

# %%
lista
# Out:
# [1, 2, 3, 4, 3.14, True, (1, 2, 3), 'Hola']

# %%
# slicing

# [lim_inf : lim_sup]  LIM_SUP ESTÁ EXCLUÍDO
lista[0 : 3]
# Out:
# [1, 2, 3]

# %%
lista[1:3]
# Out:
# [2, 3]

# %%
lista[4:7]
# Out:
# [3.14, True, (1, 2, 3)]

# %%
# [lim_inf : lim_sup]  Tanto lim_inf como LIM_SUP son OPCIONALES

lista[:]
# Out:
# [1, 2, 3, 4, 3.14, True, (1, 2, 3), 'Hola']

# %%
lista[:3]
# Out:
# [1, 2, 3]

# %%
lista[5:]
# Out:
# [True, (1, 2, 3), 'Hola']

# %% [markdown]
# ---
# Reemplazar elementos de la lista

# %%
lista
# Out:
# [1, 2, 3, 4, 3.14, True, (1, 2, 3), 'Hola']

# %%
lista[-2] = "Miguel"

# %%
lista
# Out:
# [1, 2, 3, 4, 3.14, True, 'Miguel', 'Hola']

# %%
lista[0] = 100.100

# %%
lista
# Out:
# [100.1, 2, 3, 4, 3.14, True, 'Miguel', 'Hola']

# %%
dir(lista)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
lista
# Out:
# [100.1, 2, 3, 4, 3.14, True, 'Miguel', 'Hola']

# %%
# Notación punto (.) (dot-notation)

lista.count(3.14)
# Out:
# 1

# %%
lista
# Out:
# [100.1, 2, 3, 4, 3.14, True, 'Miguel', 'Hola']

# %%
lista.append(True)

# %%
lista
# Out:
# [100.1, 2, 3, 4, 3.14, True, 'Miguel', 'Hola', True]

# %%
lista.append("UP")

# %%
lista
# Out:
# [100.1, 2, 3, 4, 3.14, True, 'Miguel', 'Hola', True, 'UP']

# %%
lista.append([1, 2, 3])

# %%
lista
# Out:
# [100.1, 2, 3, 4, 3.14, True, 'Miguel', 'Hola', True, 'UP', [1, 2, 3]]

# %%
lista.insert(4, "Hola mundo")
lista
# Out:
# [100.1,
#  2,
#  3,
#  4,
#  'Hola mundo',
#  'Hola mundo',
#  'Hola mundo',
#  'Hola mundo',
#  'Hola mundo',
#  'Hola mundo',
#  3.14,
#  True,
#  'Hola',
#  True,
#  100,
#  'UP',
#  [1, 2, 3]]

# %%
lista.insert(-2, 100)
lista
# Out:
# [100.1,
#  2,
#  3,
#  4,
#  'Hola mundo',
#  3.14,
#  True,
#  'Miguel',
#  'Hola',
#  True,
#  100,
#  'UP',
#  [1, 2, 3]]

# %%
# lista.remove('Ángel')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 lista.remove('Ángel')
#
# ValueError: list.remove(x): x not in list

# %%
lista.remove('Miguel')

# %%
lista
# Out:
# [100.1, 2, 3, 4, 'Hola mundo', 3.14, True, 'Hola', True, 100, 'UP', [1, 2, 3]]

# %%
lista.pop() # Mal uso de pop
# Out:
# [1, 2, 3]

# %%
lista
# Out:
# [100.1,
#  2,
#  3,
#  4,
#  'Hola mundo',
#  'Hola mundo',
#  'Hola mundo',
#  'Hola mundo',
#  'Hola mundo',
#  'Hola mundo',
#  3.14,
#  True,
#  'Hola',
#  True,
#  100,
#  'UP']

# %%
# Uso correcto de pop
tmp = lista.pop()

# %%
print(tmp)
print(lista)
# Out:
# UP
# [100.1, 2, 3, 4, 'Hola mundo', 'Hola mundo', 'Hola mundo', 'Hola mundo', 'Hola mundo', 'Hola mundo', 3.14, True, 'Hola', True, 100]

# %%
tmp = lista.pop(4)
print(tmp)
print(lista)
# Out:
# Hola mundo
# [100.1, 2, 3, 4, 'Hola mundo', 'Hola mundo', 'Hola mundo', 'Hola mundo', 'Hola mundo', 3.14, True, 'Hola', True, 100]

# %%
# lista_tmp = lista.copy()
lista.clear()

# %%
lista
# Out:
# []
