# %%
class Gato:
    def __init__(self, nombre, edad) -> None:
        self.__nombre = nombre # Name mangling
        self.__edad = edad

g1 = Gato('Garfield', 10)
# print(g1.__edad)
# print(g1.__nombre)

# %%
dir(g1)
# Out:
# ['_Gato__edad',
#  '_Gato__nombre',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
g2 = Gato('Minino', 2)
print(g2._Gato__edad)
print(g2._Gato__nombre)
# Out:
# 2
# Minino

# %% [markdown]
# ---

# %%
"""
1. Mochila
2. Artículo

m1 = Mochila()
a1 = Articulo('lapiz')
"""
class Mochila:
    def __init__(self, capacidad) -> None:
        self._articulos = []
        self._capacidad = capacidad
        self.peso_actual = 0

    def agregarArticulos(self, articulo:Articulo):
        if self.peso_actual + articulo._peso < self._capacidad:
            self._articulos.append(articulo)
            self.peso_actual += articulo._peso
        else:
            print("No cabe")
    
    # Setters y getters (viejito) para articulos
    def getArticulos(self):
        return self._articulos
    
    def setArticulos(self, articulo):
        self._articulos.append(articulo)

    # Setters y getters (moderno) para capacidad
    # Getter
    @property # Decoradores
    def capacidad(self):
        return self._capacidad
    
    # Setter
    @capacidad.setter
    def capacidad(self, new_capacidad):
        self._capacidad = new_capacidad

    def __str__(self) -> str:
        if len(self._articulos) == 0:
            return 'Está vacía'
        else:
            return f'Esta mochila tiene {len(self._articulos)} artículos. Ocupado {self.peso_actual}/{self._capacidad} Kg.'
    
class Articulo:
    contador = 0
    def __init__(self, nombre:str, peso:float) -> None:
        Articulo.contador += 1
        self._nombre = nombre
        self._peso = peso

# %%
a1 = Articulo('lápiz', .250)
a2 = Articulo('MacBook', 3)
m1 = Mochila(10)

# %%
a1.contador
# Out:
# 3

# %%
m1.agregarArticulos(a1)

# %%
m1.agregarArticulos(a2)

# %%
a3 = Articulo('Pesa', 10)
m1.agregarArticulos(a3)
# Out:
# No cabe

# %%
print(m1)
# Out:
# Esta mochila tiene 2 artículos. Ocupado 3.25/10 Kg.

# %%
print(m1.capacidad)
m1.capacidad = 500
print(m1.capacidad)
# Out:
# 10
# 500

# %% [markdown]
# ---

# %%
Articulo.contador
# Out:
# 3
