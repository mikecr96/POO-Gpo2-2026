# %% [markdown]
# # CONVERSIÓN DE TIPOS DE DATO
# ## CONVERSIÓN HACIA INT

# %%
int(3.14)
# Out:
# 3

# %%
int(3.999999999)
# Out:
# 3

# %%
# int("hola mundo")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 int("hola mundo")
#
# ValueError: invalid literal for int() with base 10: 'hola mundo'

# %%
int("123")
# Out:
# 123

# %%
# int("3.14")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 int("3.14")
#
# ValueError: invalid literal for int() with base 10: '3.14'

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %% [markdown]
# ## Conversión hacia float

# %%
float("3.14")
# Out:
# 3.14

# %%
float(3)
# Out:
# 3.0

# %%
# float([])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 float([])
#
# TypeError: float() argument must be a string or a real number, not 'list'

# %%
float(True)
# Out:
# 1.0

# %% [markdown]
# ## Conversión hacia bool

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(-0.0000001)
# Out:
# True

# %%
bool("0")
# Out:
# True

# %%
bool("")
# Out:
# False

# %% [markdown]
# ## Conversión hacia str

# %%
str(1)
# Out:
# '1'

# %%
str(1234)
# Out:
# '1234'

# %%
str(True)
# Out:
# 'True'

# %%
str([1, 2, 3, 4])
# Out:
# '[1, 2, 3, 4]'

# %% [markdown]
# ## Conversión hacia tuple

# %%
# tuple(123)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 tuple(123)
#
# TypeError: 'int' object is not iterable

# %%
tuple("hola")
# Out:
# ('h', 'o', 'l', 'a')

# %%
tuple([1, 2, True, (1,)])
# Out:
# (1, 2, True, (1,))

# %% [markdown]
# ## Conversión hacia list

# %%
list("mundo")
# Out:
# ['m', 'u', 'n', 'd', 'o']

# %%
list((1, 2, 3))
# Out:
# [1, 2, 3]

# %%
list({'perro':"mamífero", 'gato':'felino'})
# Out:
# ['perro', 'gato']

# %% [markdown]
# ## Conversión hacia dict

# %%
dict([1, 2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 dict([1, 2])
#
# TypeError: object is not iterable
# Cannot convert dictionary update sequence element #0 to a sequence
