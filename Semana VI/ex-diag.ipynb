# %% [markdown]
# 🟢 Examen Diagnóstico (Versión B)
#
# Instrucciones: Escribe el código necesario en Python para resolver cada uno de los siguientes 7 ejercicios.
#
# 1) Entrada, Salida y Conversión: Escribe un programa que pida al usuario ingresar dos números enteros. Calcula la suma de ambos y muestra en pantalla el resultado con el siguiente formato: "La suma de [numero1] y [numero2] es igual a [resultado]".
#
# 2) Operadores Aritméticos: Pide al usuario su peso (en kg) y su altura (en metros). Calcula su Índice de Masa Corporal (IMC) usando la fórmula $peso / altura^2$ e imprime el resultado.
#
# 3) Condicionales (if/else): Escribe un código que pregunte al usuario su edad. Si la edad es mayor o igual a 18, imprime "Eres mayor de edad"; de lo contrario, imprime "Eres menor de edad".
#
# 4) Manejo de Listas: Crea una lista que contenga 4 nombres de colores (ej. "Rojo", "Azul", "Verde", "Amarillo").Modifica la lista para que el color en la segunda posición cambie a "Morado". De la lista anterior, utiliza un método para eliminar el último color de la lista. Imprime cómo quedó la lista final.
#
# 5) Ciclos (For y Range): Utiliza un ciclo for y la función range() para imprimir todos los números pares que hay entre el 2 y el 20 (incluyendo el 20).
#
# 6) Métodos de Strings: Solicita al usuario que escriba una palabra cualquiera. Escribe el código para imprimir esa misma palabra pero en mayúsculas .upper(), y en la siguiente línea imprime cuántas letras tiene esa palabra (su longitud).
#
# 7) Definición de Funciones: Crea una función llamada calcular_doble que reciba un número como parámetro y retorne el doble de ese valor. Llama a tu función pasándole el número 15 e imprime el resultado devuelto.
